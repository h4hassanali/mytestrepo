# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hassan Ali** <br>
# Senior Data Engineer

# %% [markdown]
# I am interested in data science because I love to explore patterns and training machine learning models to predict hidden insights.

# %% [markdown]
# ### My Code is supposed to run a loop from 0 to 4 ###

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# - 1
# - 2
# - 3
# 1. A
# 2. B
# 3. C <br>
#
# |Name|Roll No|
# |----|-------|
# |Hassan|1234|
# |Ali|5675|
# |Raza|8876|
